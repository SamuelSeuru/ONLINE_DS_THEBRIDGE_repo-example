# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## PRACTICA OBLIGATORIA: ANÁLISIS UNIVARIANTE

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste en hacer el análisis univariante completo de un dataset con el que acabarás muy familiarizado, el manifiesto de pasajeros del Titanic. Descarga este notebook en tu ordenador y trabaja en local. Ten en cuenta que tendrás que descar los directorios de imágenes y datos adicionales, si los hubiera.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Ejercicio 0
#
# Importa los paquetes y módulos que necesites a lo largo del notebook. Te dejo una que vas a necesitar sí o sí

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd


# No hay imports raros son los imports de los notebooks del workout :-)
# Ahora sí que en vez de usar las funciones definidas en los workout se emplean las indicadas a lo largo de los ejercicios importándolas del módulo correspondiente

# %%
from bootcampviztools import pinta_distribucion_categoricas, plot_multiple_boxplots

# %% [markdown]
# ### #1 Preparación

# %% [markdown]
# ### #1.1

# %% [markdown]
# Carga en un dataframe los datos del titanic a partir de un dataset de seaborn. Para ello:
#
# * ejecuta ```python sns.get_dataset_names()```
# * localiza el nombre que puede ser el adecuado para el ejercicio
# * Asigna la salida de ```python sns.load_dataset(<nombre_del_dataset)``` a una variable "df_titanic"

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df_titanic = sns.load_dataset("titanic")

# %%
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ### #1.2
#
# Muestra una porción del dataset ("df_titanic") y su info general. ¿Hay nulos?

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %% [markdown]
# Si, hay nulos en las variables siguientes:
# - age
# - embarked
# - deck
# - embark_town

# %% [markdown]
# ### #1.3
#
# Obtén el porcentaje de nulos y decide que hacer con las columnas con nulos y ejecútalo. Además deshazte de la columna "parch" que no la emplearemos.

# %%
#bueno primero ver que en nuestra df esta la columna "parch" significa que normalmente, no nos hemos equivocado de df
##para eliminarla:
df_titanic = df_titanic.drop("parch", axis=1) # axis = 1 para especificar que elimino una columna
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp     fare embarked   class    who  \
# 0           0       3    male  22.0      1   7.2500        S   Third    man
# 1           1       1  female  38.0      1  71.2833        C   First  woman
# 2           1       3  female  26.0      0   7.9250        S   Third  woman
# 3           1       1  female  35.0      1  53.1000        S   First  woman
# 4           0       3    male  35.0      0   8.0500        S   Third    man
# ..        ...     ...     ...   ...    ...      ...      ...     ...    ...
# 886         0       2    male  27.0      0  13.0000        S  Second    man
# 887         1       1  female  19.0      0  30.0000        S   First  woman
# 888         0       3  female   NaN      1  23.4500        S   Third  woman
# 889         1       1    male  26.0      0  30.0000        C   First    man
# 890         0       3    male  32.0      0   7.7500        Q   Third    man
#
#      adult_male deck  embark_town alive  alone
# ...

# %%
porcentaje_nulos = df_titanic.isnull().mean() * 100

# Muestra el porcentaje de nulos en cada columna
print("Porcentaje de nulos por columna:")
porcentaje_nulos
# Out:
# Porcentaje de nulos por columna:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# deck           77.216611
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %% [markdown]
# - la columna "deck", que supongo se refiere al nivel del camarote tiene un 77% de valores nulos. Ya que tenemos la columna "clase" y que supongo que la letra del nivel del camarote esta relacionado con la clase, no me interesaria ***de momento***, asi que la voy a suprimir.
# - la columna "age" si que tiene casi un 20% de valores nulos pero prefiero quedarme con ella todavia. Quizas, si separo en 2 dos categorias (man/woman), habra menos nulos en una de estas 2 categorias y se podria analyzar de manera adecuada. asi que no la quito, ***de momento***.
# - las columnas "embarked" y "embark_town" las dejo, porque tienen bajos % de nulos.

# %%
#quitamos "deck"
df_titanic = df_titanic.drop("deck", axis=1) # axis = 1 para especificar que elimino una columna
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp     fare embarked   class    who  \
# 0           0       3    male  22.0      1   7.2500        S   Third    man
# 1           1       1  female  38.0      1  71.2833        C   First  woman
# 2           1       3  female  26.0      0   7.9250        S   Third  woman
# 3           1       1  female  35.0      1  53.1000        S   First  woman
# 4           0       3    male  35.0      0   8.0500        S   Third    man
# ..        ...     ...     ...   ...    ...      ...      ...     ...    ...
# 886         0       2    male  27.0      0  13.0000        S  Second    man
# 887         1       1  female  19.0      0  30.0000        S   First  woman
# 888         0       3  female   NaN      1  23.4500        S   Third  woman
# 889         1       1    male  26.0      0  30.0000        C   First    man
# 890         0       3    male  32.0      0   7.7500        Q   Third    man
#
#      adult_male  embark_town alive  alone
# ...

# %% [markdown]
# ### #1.4
# Sobre el dataset "limpio". Rellena la tabla de descripción (muy breve) de lo que es cada columna en función de su nombre y los valores. Para ayudarte:
# * Se trata del dataset que reune lo más parecido a un manifiesto de supervivientes y fallecidos en el viaje.
# * sibsp: Es el numero de familiares que viajan con la persona indicada en el manifiesto (lista de pasajeros)
# * embarked: Es la incial de la letra de la ciudad donde embarcó la persona.

# %% [markdown]
# objetivo de nuestro análisis -> hacer un estudio de la superviviencia y mortalidad en el viaje
#
# |Columna/Variable|Descripción|Tipo_de_Variable|Importancia inicial|Nota|
# |-|-|-|-|-|
# |survived|Se trata de la variable que indica si el pasajero ha sobrevivido (1) o no (0)|Binaria|0|he supuesto que 1 equivale a sobrevivir con la columna "alive"||
# |pclass|Clase del boleto del pasajero (1, 2 o 3)|Categorica|1|hacer un analisis de la mortalidad por clase/corresponde a la columna "class"||
# |sex|Se trata de la variable que indica el género del pasajero|Binaria|0|||
# |age|edad del pasajero|Continua|0|hemos visto que puede tener NaN values||
# |sibsp|Es el numero de familiares que viajan con la persona indicada en el manifiesto (lista de pasajeros)|Numerica Discreta|3|||
# |fare|Tarifa|Continua|2|||
# |embarked|Puerto de embarque|Categorica|2|se puede hacer un analisis de la clase dominante en cada puerto|hay que cambiar las letras por los puertos para simplicidad|
# |class|Clase|Categorica|1|igual que pclass||
# |who|tipo de persona (mujer,hombre, niño)|Categorica|0|||
# |adult_male|es el pasajero un adulto y hombre a la vez?|Binario|2|||
# |embark_town|Nombre del puerto de embarque|Categorica|2|se puede juntar con "embarked" ya que esta columna es la icicial de cada puerto||
# |alive|vivo o muerto|Binaria|0|se parece a survived||
# |alone|ha viajado el pasajero solo?|Binaria|3|||

# %% [markdown]
# ### #1.5
#
# Busca en internet las tres ciudades que visitó el Titanic antes de poner rumbo a su destino y llegar a alta mar. Cambia las iniciales por esos valores.

# %% [markdown]
# ->Yo creo que se puede tambien deducir de la columna "embarked_town" que da S por Southampton, C por Cherbourg y Q por Qeenstown

# %%
puertos = {"S": "Southampton", "C": "Cherbourg", "Q": "Queenstown"}

# Aplicar a la columna "embarked"
df_titanic["embarked"] = df_titanic["embarked"].replace(puertos)
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp     fare     embarked   class  \
# 0           0       3    male  22.0      1   7.2500  Southampton   Third
# 1           1       1  female  38.0      1  71.2833    Cherbourg   First
# 2           1       3  female  26.0      0   7.9250  Southampton   Third
# 3           1       1  female  35.0      1  53.1000  Southampton   First
# 4           0       3    male  35.0      0   8.0500  Southampton   Third
# ..        ...     ...     ...   ...    ...      ...          ...     ...
# 886         0       2    male  27.0      0  13.0000  Southampton  Second
# 887         1       1  female  19.0      0  30.0000  Southampton   First
# 888         0       3  female   NaN      1  23.4500  Southampton   Third
# 889         1       1    male  26.0      0  30.0000    Cherbourg   First
# 890         0       3    male  32.0      0   7.7500   Queenstown   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df_titanic = df_titanic.drop(["pclass" ,"embark_town"], axis=1) # axis = 1 para especificar que elimino una columna
df_titanic
# Out:
#      survived     sex   age  sibsp     fare     embarked   class    who  \
# 0           0    male  22.0      1   7.2500  Southampton   Third    man
# 1           1  female  38.0      1  71.2833    Cherbourg   First  woman
# 2           1  female  26.0      0   7.9250  Southampton   Third  woman
# 3           1  female  35.0      1  53.1000  Southampton   First  woman
# 4           0    male  35.0      0   8.0500  Southampton   Third    man
# ..        ...     ...   ...    ...      ...          ...     ...    ...
# 886         0    male  27.0      0  13.0000  Southampton  Second    man
# 887         1  female  19.0      0  30.0000  Southampton   First  woman
# 888         0  female   NaN      1  23.4500  Southampton   Third  woman
# 889         1    male  26.0      0  30.0000    Cherbourg   First    man
# 890         0    male  32.0      0   7.7500   Queenstown   Third    man
#
#      adult_male alive  alone
# 0          True    no  False
# 1         False   yes  False
# ...

# %% [markdown]
# ### #2 Análisis
#
# Sabiendo que el objetivo de nuestro análisis es hacer un estudio de la superviviencia y mortalidad en el viaje... Haz un análisis univariante completo y ordenado de las siguientes variables:
# ["survived","who","age","fare","class","embarked","alone"]
# Nota: Si quieres añadir más, perfecto.
#
# Separa el análisis en categóricas (incluyendo binarias) y numéricas. Muestra valores, gráficas y conclusiones/observaciones (2 o 3 por variable)

# %% [markdown]
# ### #2.1 Categóricas

# %% [markdown]
# Vamos a empezar con el estudio de una sola variable, como ejemplo:

# %%
#sex
df_titanic.sex.describe()
# Out:
# count      891
# unique       2
# top       male
# freq       577
# Name: sex, dtype: object

# %%
def frecuencias(df, columna_categorica, porcentaje = True):
    frec_abs = df[columna_categorica].value_counts() # Values_counts() me da las frecuencias absolutas
    frec_rel = df[columna_categorica].value_counts(normalize=True) * (100 if porcentaje else 1)  # Si activo el argumento normalize me da las relativas en tanto por 1, el argumento porcentaje de la función me permite pasarlo a tanto por cien

    # Crear DataFrame con ambas frecuencias
    frec_df = pd.DataFrame({'Frecuencia Absoluta': frec_abs, 'Frecuencia Relativa': frec_rel})

    return frec_df

# %%
# Valores numéricos:
df_frecuencias = frecuencias(df_titanic, "sex")
df_frecuencias
# Out:
#         Frecuencia Absoluta  Frecuencia Relativa
# sex
# male                    577            64.758698
# female                  314            35.241302

# %%
pinta_distribucion_categoricas(df_titanic, ["sex"], relativa= False, mostrar_valores= True, giro = 45)

# %%
pinta_distribucion_categoricas(df_titanic, ["sex"], relativa= True, mostrar_valores= True, giro = 45)

# %% [markdown]
# Hay una clara mayoría de pasajeros tipificados como género masculino (65-35) (suponemos que M es male)
#
# Los pasajeros de genero "masculino" representan un 66% de los pasajeros
#
# Los pasajeros de genero "femenino" representan un 34% de los pasajeros

# %% [markdown]
# - ahora que tengo info sobre el genero de los pasajeros, puedo investigar un poco mas analizando la variable "who", para saber cuantos eran niños

# %%
#who
df_titanic.who.describe()
# Out:
# count     891
# unique      3
# top       man
# freq      537
# Name: who, dtype: object

# %%
# Valores numéricos:
df_frecuencias = frecuencias(df_titanic, "who")
df_frecuencias
# Out:
#        Frecuencia Absoluta  Frecuencia Relativa
# who
# man                    537            60.269360
# woman                  271            30.415264
# child                   83             9.315376

# %%
pinta_distribucion_categoricas(df_titanic, ["who"], relativa= False, mostrar_valores= True, giro = 45)

# %%
pinta_distribucion_categoricas(df_titanic, ["who"], relativa= True, mostrar_valores= True, giro = 45)

# %% [markdown]
# Hay una clara mayoría de pasajeros tipificados como hombres (60-30-10)
#
# Los pasajeros de tipo hombre representan un 60% de los pasajeros
#
# Los pasajeros de tipo woman representan un 30% de los pasajeros
#
# Los pasajeros de tipo niñ@s representan un 10% de los pasajeros

# %% [markdown]
# Y ahora vamos con el estudio de las siguientes variables:
# ---
# ---

# %%
lista = ["survived","who","class","embarked","alone"]
df_titanic[lista].mode().T
# Out:
#                     0
# survived            0
# who               man
# class           Third
# embarked  Southampton
# alone            True

# %% [markdown]
# -> asi podríamos pensar que el perfil del pasajero que no ha sobrevivido (0) es un hombre de la clase 3° que ha subido solo desde Southampton

# %%
pinta_distribucion_categoricas(df_titanic, ["survived","who","class","embarked","alone"], mostrar_valores= True, relativa = True)

# %% [markdown]
# Observaciones:
# - Hay una mayoría de pasajeros que han muerto (62%-38%)
# - Hay una clara mayoría de pasajeros tipificados como hombres (60%-30%-10%)
# - Hay una clara mayoría de pasajeros perteneciendo a la Tercera Clase (55%-24%-21%)
# - Hay una clara mayoría de pasajeros que han embarcado desde Southampton (72%-19%-9%)
# - Hay una mayoría de pasarejos que han viajado solos (60%-40%)
#
# -> *Si la mayoria de los pasajeros han muerto, cual es la razon ? Puede que el barco no estaba preparado para un accidente?*  La clase ha determinado las tasas de supervivencia?*
#
# -> *Seran los hombres los que mas han muerto, ya que son representan la mayoria? -> esta pregunta tambien podria exponer si han habido politicas de salvamiento de los pasajeros* / lo utilmo se podria comprobar con estas preguntas: -> *¿Cómo afecta el tipo de persona(man/woman/children) a las tasas de supervivencia?*   -> Puede que haber viajado solo ha aumentado la probabilidad de morir si la politica era de salvar primero a los que viajaban en familia?
# -> O como lo acabo de comentar, la clase ha influido sobre la probababilidad de sobrevivir?*
#
# -> *La mayoria de los pasajeros han embarcado desde Southampton: -> Habria cambiado algo en el numero de fallecidos si el barco no hubiera hecho esta parada en Southampton?*
#
# -> *La edad ha influido sobre la probababilidad de sobrevivir?*
#
# -> *El numero del camarote estando relacionado con su localizacion dentro del barco, ha podido influir sobre la probababilidad de sobrevivir?*

# %% [markdown]
# ### #2.2 Numéricas

# %%
df_titanic.describe()
# Out:
#          survived         age       sibsp        fare
# count  891.000000  714.000000  891.000000  891.000000
# mean     0.383838   29.699118    0.523008   32.204208
# std      0.486592   14.526497    1.102743   49.693429
# min      0.000000    0.420000    0.000000    0.000000
# 25%      0.000000   20.125000    0.000000    7.910400
# 50%      0.000000   28.000000    0.000000   14.454200
# 75%      1.000000   38.000000    1.000000   31.000000
# max      1.000000   80.000000    8.000000  512.329200

# %%
df_titanic.describe().loc["50%"]
# Out:
# survived     0.0000
# age         28.0000
# sibsp        0.0000
# fare        14.4542
# Name: 50%, dtype: float64

# %% [markdown]
# -> hay una diferencia entre la media y la mediana de "survived", "sibsp" y "fare", mientras para "age", hay una diferencia relativamente pequeña(1.7 year)
# --> lo vamos a visualizar con diagrama de cajas

# %% [markdown]
# *1. Diagrama de caja para las variables numericas*

# %%
columnas_numericas_titanic = [
    "age",
    "fare"
]
#columnas_numericas_titanic = df_titanic.describe().T.index.to_list()
columnas_numericas_titanic
# Out:
# ['age', 'fare']

# %%
plot_multiple_boxplots(df_titanic, columnas_numericas_titanic)

# %% [markdown]
# Observaciones:
# - Hay una relativa simetria con la variable "age", con varios outliers encima de Q3=65 years
# - Hay menos simetria con la variable "fare", con muchos outliers encima de Q3= 80. -> De que habrá dependido la tarifa? de la clase? de los puertos de embarque?
#
#  **Observacion general:**
#   - En general no parecen variables muy dispersas,  pero hay bastantes valores anómalos , sobre todo con "fare"
#   - No olvidemos:  nuestro objetivo es de estudiar la supervivencia y mortalidad en el viaje del Titanic. Dado que la edad es una de las variables directoras, tendremos que tenerlo en cuenta para analizar mejor esa distribución y esos valores anómalos encima de 65 años antes de comparar "age" con el resto de variables demográficas y categóricas.

# %% [markdown]
# -> veamos los rangos:

# %%
df_titanic.describe().loc["max"] - df_titanic.describe().loc["min"]
# Out:
# survived      1.0000
# age          79.5800
# sibsp         8.0000
# fare        512.3292
# dtype: float64

# %% [markdown]
# -> para"age", hay un rango de casi 80 años, (claro con las familias viajando con abuelos y bébés)
#
# seguimos con el analisis

# %%
# para comparar la deviacion estandar con la media, usamos el CV:
def variabilidad(df):
    df_var = df.describe().loc[["std","mean"]].T
    df_var["CV"] = df_var["std"]/df_var["mean"]
    return df_var

# %%
variabilidad(df_titanic)
# Out:
#                 std       mean        CV
# survived   0.486592   0.383838  1.267701
# age       14.526497  29.699118  0.489122
# sibsp      1.102743   0.523008  2.108464
# fare      49.693429  32.204208  1.543073

# %% [markdown]
# Para las series "age" y "fare", los CV son mas altos que 30% (o 0.30), se consideran como una alta variabilidad.
#
# -tenemos que mirar mejor la distribucion de "age"

# %%
df_titanic["age"].hist()
# Out:
# <Axes: >

# %% [markdown]
# Existe una dispersion y la distribución de los valores se concentra mucho en un rango medio, alrededor de 28 years

# %%
def plot_histo_den(df, columns):
    num_cols = len(columns)
    num_rows = num_cols // 2 + num_cols % 2
    fig, axes = plt.subplots(num_rows, 2, figsize=(12, 6 * num_rows))
    axes = axes.flatten()

    for i, column in enumerate(columns):
        if df[column].dtype in ['int64', 'float64']:
            sns.histplot(df[column], kde=True, ax=axes[i])
            axes[i].set_title(f'Histograma y KDE de {column}')

    # Ocultar ejes vacíos
    for j in range(i + 1, num_rows * 2):
        axes[j].axis('off')

    plt.tight_layout()
    plt.show()
    
plot_histo_den(df_titanic,["age"])

# %% [markdown]
# -looks this way.

# %% [markdown]
# ![image.png](attachment:5e653119-7bca-4dee-89fa-657238d39877.png)

# %% [markdown]
# Como la densidad estimada en el diagrama combinado histograma-densidad se parece a una normal, entonces un buen criterio es obtener la desviación estándar de nuestra variable "age" y considerar outliers a aquellos valores que superen 2 o 3 veces la desviación  a la izquierda y derecha(valores < media - std*n) y (valores > media + std*n)

# %%
def plot_combined_graphs(df, columns, whisker_width=1.5):
    num_cols = len(columns)
    if num_cols:
        
        fig, axes = plt.subplots(num_cols, 2, figsize=(12, 5 * num_cols))
        print(axes.shape)

        for i, column in enumerate(columns):
            if df[column].dtype in ['int64', 'float64']:
                # Histograma y KDE
                sns.histplot(df[column], kde=True, ax=axes[i,0] if num_cols > 1 else axes[0])
                if num_cols > 1:
                    axes[i,0].set_title(f'Histograma y KDE de {column}')
                else:
                    axes[0].set_title(f'Histograma y KDE de {column}')

                # Boxplot
                sns.boxplot(x=df[column], ax=axes[i,1] if num_cols > 1 else axes[1], whis=whisker_width)
                if num_cols > 1:
                    axes[i,1].set_title(f'Boxplot de {column}')
                else:
                    axes[1].set_title(f'Boxplot de {column}')

        plt.tight_layout()
        plt.show()

# %%
plot_combined_graphs(df_titanic, ["age"], whisker_width= 3) # 2 veces la longitud habitual (que es 1.5*IQR)
# Out:
# (2,)

# %% [markdown]
# Así de primeras no hay outliers, y si nos fijamos en los histogramas es cierto que no se ven valores extremos. En este caso, capítulo cerrado.

# %%
plot_combined_graphs(df_titanic, ["fare"], whisker_width= 4.5) # 2 veces la longitud habitual (que es 1.5*IQR)
# Out:
# (2,)

# %% [markdown]
# "fare" es una variable clara sobre la que tratar los outliers:
#
# Habria que ver a que corresponde esta valor encima de 500: es un error?
#
# Me apunto también un análisis que podría ser interesante:
# *¿coinciden los outliers de "fare" que corresponden a tarifas muy altas con los pasarejos de primera clase y que han sobrevivido?*

# %%
umbral = 150

df_sin_outlier = df_titanic.loc[df_titanic.fare < umbral].copy()
df_con_outlier = df_titanic.loc[df_titanic.fare >= umbral].copy()

# %%
plot_combined_graphs(df_sin_outlier,["fare"])
# Out:
# (2,)

# %%
plot_combined_graphs(df_con_outlier,["fare"])
# Out:
# (2,)

# %% [markdown]
# Parece este valor superior a 500 un caso a parte.
